# %%
# %pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 KB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 2.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.63 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %%
# !wget https://app.roboflow.com/ds/NTSxpBVEq5?key=yRexjaMvCR
# Out:
# --2023-04-05 13:52:31--  https://app.roboflow.com/ds/NTSxpBVEq5?key=yRexjaMvCR
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/bFNc899uMuNCaJJFJHPGRH87suv1/MCBPFPwwSfTJc9zckuXq/2/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230405%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230405T135232Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip -q /content/NTSxpBVEq5?key=yRexjaMvCR -d datasets && rm /content/NTSxpBVEq5?key=yRexjaMvCR

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:10<00:00, 77.3MB/s]
# rm: cannot remove 'tmp.zip  # unzip': No such file or directory

# %%
# Train YOLOv8n on COCO128 for 3 epochs
# !yolo train model=yolov8n.pt data=/content/datasets/data.yaml epochs = 100 imgsz = 640
# Out:
# Ultralytics YOLOv8.0.63 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Validate YOLOv8n on COCO128 val
# !yolo val model=/content/runs/detect/train/weights/best.pt data=/content/datasets/data.yaml
# Out:
# 2023-04-04 19:36:46.542874: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 19:36:47.482911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/valid/labels.cache... 1298 images, 0 backgrounds, 0 corrupt: 100% 1298/1298 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 82/82 [00:18<00:00,  4.55it/s]
#                    all       1298       1301      0.637      0.437      0.571      0.417
# ...
